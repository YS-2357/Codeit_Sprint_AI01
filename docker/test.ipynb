# %%
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 13.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 12.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 7.7 MB/s eta 0:00:00ta 0:00:01
# ...

# %%
import pandas as pd

df = pd.DataFrame((1, 2))
print(df)
# Out:
#    0
# 0  1
# 1  2

# %%
df.to_csv('test.csv', index=False)

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ------------
# alembic                       1.12.0
# anyio                         4.0.0
# argon2-cffi                   23.1.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.3.0
# asttokens                     2.4.0
# async-generator               1.10
# async-lru                     2.0.4
# attrs                         23.1.0
# Babel                         2.13.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.5
# beautifulsoup4                4.12.2
# bleach                        6.1.0
# blinker                       1.6.3
# boltons                       23.0.0
# Brotli                        1.1.0
# cached-property               1.5.2
# certifi                       2023.7.22
# certipy                       0.1.3
# cffi                          1.16.0
# charset-normalizer            3.3.0
# colorama                      0.4.6
# ...
